# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("CELL.csv", index_col=[0,1])
data['Cell1 Voltage'] = data['Cell1 Cathode vPhi'] - data['Cell1 Anode vPhi']
data
# Out:
#                 Time  Cell1 Cathode vConcentration  Cell1 Cathode vPhi  \
# C1   0      0.000000                  25777.500000            4.133024
#      1     72.727273                  26055.712206            4.120677
#      2    145.454545                  26265.511209            4.112147
#      3    218.181818                  26474.378755            4.104069
#      4    290.909091                  26683.227825            4.096353
# ...              ...                           ...                 ...
# C500 56  4072.727273                  34499.775428            4.114964
#      57  4145.454545                  34290.927884            4.118556
#      58  4218.181818                  34082.080340            4.122205
#      59  4290.909091                  33873.232795            4.125909
#      60  4316.535318                  33799.643144            4.127229
#
#          Cell1 Anode vConcentration  Cell1 Anode vPhi  \
# C1   0                 22610.700000          0.197320
#      1                 22345.807076          0.198084
#      2                 22119.064935          0.198741
#      3                 21892.337099          0.199407
#      4                 21665.609401          0.200079
# ...                             ...               ...
# C500 56                12957.212394          0.028761
#      57                13183.920885          0.028334
#      58                13410.629231          0.027884
#      59                13637.337400          0.027411
#      60                13717.220384          0.027239
#
#          Cell1 Anode vSEI Length  Cell1 Voltage
# C1   0              5.000000e-09       3.935704
#      1              5.000000e-09       3.922592
#      2              5.000000e-09       3.913406
#      3              5.000000e-09       3.904662
#      4              5.000000e-09       3.896273
# ...                          ...            ...
# C500 56             1.086775e-08       4.086203
#      57             1.086836e-08       4.090222
#      58             1.086898e-08       4.094320
#      59             1.086960e-08       4.098498
#      60             1.086982e-08       4.099990
#
# [30616 rows x 7 columns]

# %%
for i in range(3, 501, 2):
    plt.plot(data.loc[(f'C{i}'),'Time'], data.loc[(f'C{i}'),'Cell1 Voltage'])

# %%
plt.plot(data.loc[(f'C3'),'Time'], data.loc[(f'C3'),'Cell1 Voltage'])
plt.plot(data.loc[(f'C499'),'Time'], data.loc[(f'C499'),'Cell1 Voltage'])
